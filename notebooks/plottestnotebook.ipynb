# %%
from pathlib import Path

# %%
import matplotlib.pyplot as plt

# %%
from modules.figures import _create_figure #, create_figure

# %%
path_to_datasets = Path("./datasets/")
path_to_T_series = path_to_datasets / "raw/OTAC_temperature_series/"

# %%
figure = _create_figure(
    path_to_T_series,
    colormap="inferno",
    x_label="$q$ / $\mathrm{nm}^{-1}$",
    x_ticks=[0, 1, 2, 3, 4, 5, 6, 7],
    y_label="$T$ / °C",
    y_limit=(0, 100),
    z_label="$I$ / $a.u.$",
    plot_marker=","
)
plt.show()
